# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
stat=pd.read_excel("Corona_gov.xlsx",index_col="State")

# %%
stat.head(3)
# Out:
#                 Confirmed  Cured  Death
# State
# AndhraPradesh         363      7      6
# AndamanNicobar         11      0      0
# Bihar                  60      0      1

# %%
stat.sort_values("Confirmed",ascending=False).head().plot(kind="barh")

# %%
stat.plot(kind="barh")
